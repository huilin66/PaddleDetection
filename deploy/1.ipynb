# %%
# !python E:\repository\defectdet\BDDetection\Bin\Win64\plugin\pythonv3plugin\libs\ppyolo\infer.py \
           --model_dir=E:\repository\defectdet\BDDetection\Bin\Win64\plugin\pythonv3plugin\libs\ppyolo\models \
           --image_file=E:\repository\defectdet\BDDetection\dataddd\input\1701661721.7274697.jpg --device=GPU \
           --output_dir=E:\repository\defectdet\BDDetection\dataddd\vis \
           --slice_infer --slice_size 640 640 --overlap_ratio 0.1 0.1
# Out:
# -----------  Running Arguments -----------
# action_file: None
# batch_size: 1
# camera_id: -1
# C:\Users\USER\.conda\envs\env_bddetection_deploy\lib\site-packages\win32\lib\pywintypes.py:2: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp, sys, os
# combine_method: nms
# cpu_threads: 1
# device: GPU
# enable_mkldnn: False
# enable_mkldnn_bfloat16: False
# image_dir: None
# image_file: E:\repository\defectdet\BDDetection\dataddd\input\1701661721.7274697.jpg
# match_metric: ios
# match_threshold: 0.6
# model_dir: E:\repository\defectdet\BDDetection\Bin\Win64\plugin\pythonv3plugin\libs\ppyolo\models
# output_dir: E:\repository\defectdet\BDDetection\dataddd\vis
# overlap_ratio: [0.1, 0.1]
# random_pad: False
# reid_batch_size: 50
# reid_model_dir: None
# run_benchmark: False
# run_mode: paddle
# save_images: True
# save_mot_txt_per_img: False
# save_mot_txts: False
# save_results: False
# ...
