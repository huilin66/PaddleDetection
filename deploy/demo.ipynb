# %%
# !python /mnt/e/repository/PaddleDetection/deploy/python/infer.py \
        --model_dir=/mnt/e/data/DefectDet/ppyoloe_plus_l_defect_contrast \
        --image_file=/mnt/e/repository/defectdet/BDDetection/dataddd/input/1701661721.7274697.jpg --device=GPU \
        --output_dir=/mnt/e/repository/defectdet/BDDetection/dataddd/vis \
        --slice_infer --slice_size 640 640 --overlap_ratio 0.1 0.1
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# -----------  Running Arguments -----------
# action_file: None
# batch_size: 1
# camera_id: -1
# combine_method: nms
# cpu_threads: 1
# device: GPU
# enable_mkldnn: False
# enable_mkldnn_bfloat16: False
# image_dir: None
# image_file: /mnt/e/repository/defectdet/BDDetection/dataddd/input/1701661721.7274697.jpg
# match_metric: ios
# match_threshold: 0.6
# model_dir: /mnt/e/data/DefectDet/ppyoloe_plus_l_defect_contrast
# output_dir: /mnt/e/repository/defectdet/BDDetection/dataddd/vis
# overlap_ratio: [0.1, 0.1]
# random_pad: False
# reid_batch_size: 50
# reid_model_dir: None
# run_benchmark: False
# run_mode: paddle
# save_images: True
# save_mot_txt_per_img: False
# save_mot_txts: False
# save_results: False
# scaled: False
# slice_infer: True
# slice_size: [640, 640]
# threshold: 0.5
# ...

# %%
# !python python/infer.py --model_dir=E:\data\DefectDet\ppyoloe_plus_l_defect_contrast --image_file=E:\repository\defectdet\BDDetection\dataddd\input\1701661721.7274697.jpg --device=GPU --output_dir=E:\repository\defectdet\BDDetection\dataddd\vis --slice_infer --slice_size 640 640 --overlap_ratio 0.1 0.1
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# -----------  Running Arguments -----------
# action_file: None
# batch_size: 1
# camera_id: -1
# combine_method: nms
# cpu_threads: 1
# device: GPU
# enable_mkldnn: False
# enable_mkldnn_bfloat16: False
# image_dir: None
# image_file: /mnt/e/repository/defectdet/BDDetection/dataddd/input/1701661721.7274697.jpg
# match_metric: ios
# match_threshold: 0.6
# model_dir: /mnt/e/data/DefectDet/ppyoloe_plus_l_defect_contrast
# output_dir: /mnt/e/repository/defectdet/BDDetection/dataddd/vis
# overlap_ratio: [0.1, 0.1]
# random_pad: False
# reid_batch_size: 50
# reid_model_dir: None
# run_benchmark: False
# run_mode: paddle
# save_images: True
# save_mot_txt_per_img: False
# save_mot_txts: False
# save_results: False
# scaled: False
# slice_infer: True
# slice_size: [640, 640]
# threshold: 0.5
# ...

# %%
import sahi
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# -----------  Running Arguments -----------
# action_file: None
# batch_size: 1
# camera_id: -1
# combine_method: nms
# cpu_threads: 1
# device: GPU
# enable_mkldnn: False
# enable_mkldnn_bfloat16: False
# image_dir: None
# image_file: /mnt/e/repository/defectdet/BDDetection/dataddd/input/1701661721.7274697.jpg
# match_metric: ios
# match_threshold: 0.6
# model_dir: /mnt/e/repository/defectdet/BDDetection/Bin/Win64/plugin/pythonv3plugin/libs/ppyolo/models
# output_dir: /mnt/e/repository/defectdet/BDDetection/dataddd/vis
# overlap_ratio: [0.1, 0.1]
# random_pad: False
# reid_batch_size: 50
# reid_model_dir: None
# run_benchmark: False
# run_mode: paddle
# save_images: True
# save_mot_txt_per_img: False
# save_mot_txts: False
# save_results: False
# scaled: False
# slice_infer: True
# ...

# %%
# !python python/demo.py
# Out:
# 0.11.14
