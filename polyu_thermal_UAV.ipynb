# %%
# !python tools/yolo2coco.py \
    --list_path /mnt/e/data/polyu/ExpData/PolyUOutdoor_UAV/train.txt \
    --root_dir /mnt/e/data/polyu/ExpData/PolyUOutdoor_UAV \
    --save_path /mnt/e/data/polyu/ExpData/PolyUOutdoor_UAV/coco_format \
    --random_split --split_by_file
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Loading data from  /mnt/e/data/polyu/ExpData/PolyUOutdoor_UAV
# spliting mode: random split
# NUMS of train:val:test = 182:46:0
# 100%|█████████████████████████████████████████| 228/228 [00:04<00:00, 51.52it/s]
# Save annotation to /mnt/e/data/polyu/ExpData/PolyUOutdoor_UAV/annotations/train.json
# Save annotation to /mnt/e/data/polyu/ExpData/PolyUOutdoor_UAV/annotations/val.json
# Save annotation to /mnt/e/data/polyu/ExpData/PolyUOutdoor_UAV/annotations/test.json

# %%
# !python tools/train.py \
    -c configs/polyu_thermal_UAV/ppyoloe_l.yml \
    --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [11/22 19:10:10] ppdet.data.source.coco INFO: Load [20 samples valid, 162 samples invalid] in file /mnt/e/data/polyu/ExpData/PolyUOutdoor_UAV/annotations/train.json.
# W1122 19:10:10.224650 1696571 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1122 19:10:10.243502 1696571 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/22 19:10:16] ppdet.engine INFO: Epoch: [0] [0/2] learning_rate: 0.000000 loss: 4.263327 loss_cls: 0.737265 loss_iou: 0.843782 loss_dfl: 2.833213 loss_l1: 5.281933 eta: 0:11:24 batch_cost: 3.4223 data_cost: 0.0004 ips: 2.3376 images/s
# ...

# %%
import json
import os, cv2


#  可视化coco格式json标注中的box到图片上
import json
import shutil
import cv2
import os
def select(json_path, outpath, image_path):
    if not os.path.exists(outpath):
        os.makedirs(outpath)
    json_file = open(json_path)
    infos = json.load(json_file)
    images = infos["images"]
    annos = infos["annotations"]
    for i in range(len(images)):
        im_id = images[i]["id"]
        im_path = image_path + "/" + images[i]["file_name"]
        # print(im_path)
        img = cv2.imread(im_path)
        for j in range(len(annos)):
            if annos[j]["image_id"] == im_id:
                if annos[j]["image_id"] == '185':
                    print(annos[j]["bbox"])
                x, y, w, h = annos[j]["bbox"]
                x, y, w, h = int(x), int(y), int(w), int(h)
                x2, y2 = x + w, y + h
                # object_name = annos[j][""]
                if annos[j]["category_id"] == 0:
                    img = cv2.rectangle(img, (x, y), (x2, y2), (255, 0, 0), thickness=2)
                elif annos[j]["category_id"] == 1:
                    img = cv2.rectangle(img, (x, y), (x2, y2), (0, 255, 0), thickness=2)
                else:
                    print(img_name)
                    img = cv2.rectangle(img, (x, y), (x2, y2), (0, 0, 255), thickness=2)
                img_name = outpath + "/" + images[i]["file_name"]
                # print(img_name)
                # print(img.shape)
                cv2.imwrite(img_name, img)
                # continue
        # print(i)

if __name__ == "__main__":
    train_json = r'/mnt/e/data/polyu/ExpData/PolyUOutdoor_UAV/annotations/train.json'
    train_path = r'/mnt/e/data/polyu/ExpData/PolyUOutdoor_UAV/images'
    visual_output = r'/mnt/e/data/polyu/ExpData/PolyUOutdoor_UAV/vis'

    select(train_json, visual_output, train_path)

# %%
train_json = r'/mnt/e/data/polyu/data202311/msx_coco/annotations/instance_train.json'
train_path = r'/mnt/e/data/polyu/data202311/msx_coco/train'
visual_output = r'/mnt/e/data/polyu/data202311/msx_coco/vis'
select(train_json, visual_output, train_path)
# Out:
# /mnt/e/data/polyu/data202311/msx_coco/vis/FLIR3693.jpg
# /mnt/e/data/polyu/data202311/msx_coco/vis/FLIR3699.jpg
# /mnt/e/data/polyu/data202311/msx_coco/vis/FLIR3701.jpg
# /mnt/e/data/polyu/data202311/msx_coco/vis/FLIR3703.jpg
# /mnt/e/data/polyu/data202311/msx_coco/vis/FLIR3713.jpg
# /mnt/e/data/polyu/data202311/msx_coco/vis/FLIR3715.jpg
# /mnt/e/data/polyu/data202311/msx_coco/vis/FLIR3717.jpg
# /mnt/e/data/polyu/data202311/msx_coco/vis/FLIR3723.jpg
# /mnt/e/data/polyu/data202311/msx_coco/vis/FLIR3727.jpg
# /mnt/e/data/polyu/data202311/msx_coco/vis/FLIR3727.jpg
# /mnt/e/data/polyu/data202311/msx_coco/vis/FLIR3733.jpg
# /mnt/e/data/polyu/data202311/msx_coco/vis/FLIR3737.jpg
# /mnt/e/data/polyu/data202311/msx_coco/vis/FLIR3737.jpg
# /mnt/e/data/polyu/data202311/msx_coco/vis/FLIR3737.jpg
# /mnt/e/data/polyu/data202311/msx_coco/vis/FLIR3737.jpg
# /mnt/e/data/polyu/data202311/msx_coco/vis/FLIR3737.jpg
# /mnt/e/data/polyu/data202311/msx_coco/vis/FLIR3737.jpg
# ...

# %%
# Out:
# Running verify PaddlePaddle program ...
# I1207 14:16:54.697039 10922 interpretercore.cc:237] New Executor is Running.
# W1207 14:16:54.697604 10922 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1207 14:16:54.721294 10922 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# PaddlePaddle works well on 1 GPU.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.
# I1207 14:16:58.042595 10922 interpreter_util.cc:518] Standalone Executor is Used.
