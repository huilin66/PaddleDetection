# %%
# import torch
# torch.cuda.is_available()
# Out:
# True

# %%
# import paddle
# paddle.utils.run_check()

# %%
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!
# [11/22 11:13:04] ppdet.data.source.coco INFO: Load [2699 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/_annotations.coco.json.
# W1122 11:13:04.925588 1617544 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1122 11:13:04.953810 1617544 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/22 11:13:10] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_contrast.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# [10/16 10:30:21] ppdet.data.source.coco INFO: Load [2699 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/_annotations.coco.json.
# W1016 10:30:21.666287  1372 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1016 10:30:21.694006  1372 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [10/16 10:30:25] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_damage.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [10/17 20:21:25] ppdet.data.source.coco INFO: Load [526 samples valid, 0 samples invalid] in file /mnt/e/data/Damage/train/_annotations.coco.json.
# W1017 20:21:25.071552 63051 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1017 20:21:25.079722 63051 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [10/17 20:21:27] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [2] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_damage_contrast.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [10/17 16:22:59] ppdet.data.source.coco INFO: Load [526 samples valid, 0 samples invalid] in file /mnt/e/data/Damage/train/_annotations.coco.json.
# W1017 16:22:59.666512 44114 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1017 16:22:59.671584 44114 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [10/17 16:23:01] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [2] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_damage_prompt.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# Traceback (most recent call last):
#   File "tools/train.py", line 202, in <module>
#     main()
#   File "tools/train.py", line 156, in main
#     cfg = load_config(FLAGS.config)
#   File "/mnt/e/repository/PaddleDetection/ppdet/core/workspace.py", line 124, in load_config
#     cfg = _load_config_with_base(file_path)
#   File "/mnt/e/repository/PaddleDetection/ppdet/core/workspace.py", line 88, in _load_config_with_base
#     with open(file_path) as f:
# FileNotFoundError: [Errno 2] No such file or directory: 'configs/ppyoloe/ppyoloe_l_80e_damage_prompt.yml'

# %%
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_prompt.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!
# [10/17 20:38:55] ppdet.data.source.coco INFO: Load [2699 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/_annotations.coco.json.
# W1017 20:38:55.313158 71471 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1017 20:38:55.316706 71471 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [10/17 20:38:57] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# !python tools/eval.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_prompt.yml \
        --classwise
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# W1018 15:15:11.474988 259097 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1018 15:15:11.522125 259097 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [10/18 15:15:16] ppdet.data.source.coco INFO: Load [464 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/valid/_annotations.coco.json.
# [10/18 15:15:18] ppdet.utils.checkpoint INFO: Finish loading model weights: output/ppyoloe_l_80e_defect_prompt/best_model.pdparams
# [10/18 15:15:22] ppdet.engine INFO: Eval iter: 0
# [10/18 15:15:30] ppdet.metrics.metrics INFO: The bbox result is saved to bbox.json.
# loading annotations into memory...
# ...

# %%
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# [10/25 17:51:48] ppdet.data.source.coco INFO: Load [2699 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/_annotations.coco.json.
# W1025 17:51:49.003669  2467 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1025 17:51:49.006631  2467 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [10/25 17:51:50] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_prompt.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# [10/18 20:57:59] ppdet.data.source.coco INFO: Load [2699 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/_annotations.coco.json.
# W1018 20:57:59.241106 330722 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1018 20:57:59.250579 330722 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [10/18 20:58:01] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# !python tools/eval.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_prompt.yml \
        --classwise
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# W1030 17:23:17.113294  4511 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1030 17:23:17.118479  4511 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# [10/30 17:23:19] ppdet.data.source.coco INFO: Load [464 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/valid/_annotations.coco.json.
# [10/30 17:23:20] ppdet.utils.checkpoint INFO: Finish loading model weights: output/ppyoloe_l_80e_defect_prompt/best_model.pdparams
# [10/30 17:23:21] ppdet.engine INFO: Eval iter: 0
# [10/30 17:23:25] ppdet.engine INFO: Eval iter: 100
# [10/30 17:23:29] ppdet.engine INFO: Eval iter: 200
# ...

# %%
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_prompt1.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# [10/22 14:01:33] ppdet.data.source.coco INFO: Load [2699 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/_annotations.coco.json.
# W1022 14:01:33.831844 18748 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1022 14:01:33.859539 18748 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [10/22 14:01:37] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# !python tools/eval.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_prompt1.yml \
        --classwise
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# W1030 17:20:29.059839  3630 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1030 17:20:29.091356  3630 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# [10/30 17:20:35] ppdet.data.source.coco INFO: Load [464 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/valid/_annotations.coco.json.
# [10/30 17:20:37] ppdet.utils.checkpoint INFO: Finish loading model weights: output/ppyoloe_l_80e_defect_prompt1/best_model.pdparams
# [10/30 17:20:41] ppdet.engine INFO: Eval iter: 0
# [10/30 17:20:45] ppdet.engine INFO: Eval iter: 100
# [10/30 17:20:48] ppdet.engine INFO: Eval iter: 200
# ...

# %%
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_prompt3.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# [11/02 17:11:48] ppdet.data.source.coco INFO: Load [2699 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/_annotations.coco.json.
# W1102 17:11:48.250211 23482 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1102 17:11:48.254528 23482 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/02 17:11:50] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_contrast.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# [11/03 15:59:49] ppdet.data.source.coco INFO: Load [2699 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/_annotations.coco.json.
# W1103 15:59:49.276965  4399 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1103 15:59:49.281734  4399 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/03 15:59:51] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_contrast1.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# [11/06 17:20:58] ppdet.data.source.coco INFO: Load [2699 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/_annotations.coco.json.
# W1106 17:20:58.903095 47826 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1106 17:20:58.906883 47826 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/06 17:21:00] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_contrast2.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# [11/07 20:07:19] ppdet.data.source.coco INFO: Load [2699 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/_annotations.coco.json.
# W1107 20:07:19.391297 89496 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1107 20:07:19.395939 89496 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/07 20:07:21] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_contrast3.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# [11/05 06:26:42] ppdet.data.source.coco INFO: Load [2699 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/_annotations.coco.json.
# W1105 06:26:42.787555 30431 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1105 06:26:42.792898 30431 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/05 06:26:45] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_contrast4.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.06s)
# creating index...
# index created!
# [11/07 07:10:11] ppdet.data.source.coco INFO: Load [2699 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/_annotations.coco.json.
# W1107 07:10:11.116122 75317 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1107 07:10:11.119721 75317 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/07 07:25:44] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# !python E:\repository\PaddleDetection\tools\infer.py
# Out:
# ...
# [12/07 14:29:24] ppdet.utils.checkpoint INFO: Finish loading model weights: output/ppyoloe_l_80e_defect/best_model.pdparams
# W1207 14:29:24.053639 34452 gpu_resources.cc:61] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 10.2
# W1207 14:29:24.148284 34452 gpu_resources.cc:91] device: 0, cuDNN Version: 7.6.
# C:\Users\USER\.conda\envs\env_bddetection_deploy\lib\site-packages\win32\lib\pywintypes.py:2: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   import imp, sys, os
# ...
# Traceback (most recent call last):
#   File "E:\repository\PaddleDetection\tools\infer.py", line 236, in <module>
#     main()
#   File "E:\repository\PaddleDetection\tools\infer.py", line 232, in main
#     run(FLAGS, cfg)
#   File "E:\repository\PaddleDetection\tools\infer.py", line 166, in run
#     images = get_test_images(FLAGS.infer_dir, FLAGS.infer_img)
# ...
