# %%
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_contrast1.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# Warning: Unable to use numba in PP-Tracking, please install numba, for example(python3.7): `pip install numba==0.56.4`
# Warning: import ppdet from source directory without installing, run 'python setup.py install' to install ppdet firstly
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# [11/06 16:46:58] ppdet.data.source.coco INFO: Load [2699 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/_annotations.coco.json.
# W1106 16:46:58.908345 46586 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1106 16:46:58.911401 46586 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/06 16:47:00] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# [11/06 16:47:00] ppdet.utils.checkpoint INFO: The shape [365, 768, 3, 3] in pretrained weight yolo_head.pred_cls.0.weight is unmatched with the shape [7, 768, 3, 3] in model yolo_head.pred_cls.0.weight. And the weight yolo_head.pred_cls.0.weight will not be loaded
# [11/06 16:47:00] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.1.bias is unmatched with the shape [7] in model yolo_head.pred_cls.1.bias. And the weight yolo_head.pred_cls.1.bias will not be loaded
# [11/06 16:47:00] ppdet.utils.checkpoint INFO: The shape [365, 384, 3, 3] in pretrained weight yolo_head.pred_cls.1.weight is unmatched with the shape [7, 384, 3, 3] in model yolo_head.pred_cls.1.weight. And the weight yolo_head.pred_cls.1.weight will not be loaded
# [11/06 16:47:00] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.2.bias is unmatched with the shape [7] in model yolo_head.pred_cls.2.bias. And the weight yolo_head.pred_cls.2.bias will not be loaded
# [11/06 16:47:00] ppdet.utils.checkpoint INFO: The shape [365, 192, 3, 3] in pretrained weight yolo_head.pred_cls.2.weight is unmatched with the shape [7, 192, 3, 3] in model yolo_head.pred_cls.2.weight. And the weight yolo_head.pred_cls.2.weight will not be loaded
# [11/06 16:47:00] ppdet.utils.checkpoint INFO: Finish loading model weights: /home/dl/.cache/paddle/weights/ppyoloe_crn_l_obj365_pretrained.pdparams
# [11/06 16:47:02] ppdet.engine INFO: Epoch: [0] [   0/1349] learning_rate: 0.000000 loss: 6.354706 loss_cls: 2.765231 loss_iou: 0.408479 loss_dfl: 2.425751 loss_l1: 2.139431 loss_contrast: 6.777005 eta: 2 days, 22:06:09 batch_cost: 1.8708 data_cost: 0.0003 ips: 1.0691 images/s
# [11/06 16:47:20] ppdet.engine INFO: Epoch: [0] [ 100/1349] learning_rate: 0.000001 loss: 6.076849 loss_cls: 2.751916 loss_iou: 0.406183 loss_dfl: 1.997568 loss_l1: 1.442227 loss_contrast: 6.742949 eta: 6:08:09 batch_cost: 0.1468 data_cost: 0.0001 ips: 13.6241 images/s
# [11/06 16:47:37] ppdet.engine INFO: Epoch: [0] [ 200/1349] learning_rate: 0.000003 loss: 5.922036 loss_cls: 2.835647 loss_iou: 0.353961 loss_dfl: 1.751801 loss_l1: 1.281961 loss_contrast: 6.708393 eta: 5:48:41 batch_cost: 0.1467 data_cost: 0.0001 ips: 13.6346 images/s
# [11/06 16:47:54] ppdet.engine INFO: Epoch: [0] [ 300/1349] learning_rate: 0.000004 loss: 5.234343 loss_cls: 2.298732 loss_iou: 0.319054 loss_dfl: 1.573423 loss_l1: 1.117105 loss_contrast: 6.379697 eta: 5:44:56 batch_cost: 0.1506 data_cost: 0.0001 ips: 13.2781 images/s
# [11/06 16:48:13] ppdet.engine INFO: Epoch: [0] [ 400/1349] learning_rate: 0.000006 loss: 4.567991 loss_cls: 1.763230 loss_iou: 0.308672 loss_dfl: 1.559662 loss_l1: 1.026629 loss_contrast: 5.782296 eta: 5:51:25 batch_cost: 0.1658 data_cost: 0.0001 ips: 12.0600 images/s
# [11/06 16:48:31] ppdet.engine INFO: Epoch: [0] [ 500/1349] learning_rate: 0.000007 loss: 4.251039 loss_cls: 1.668989 loss_iou: 0.294424 loss_dfl: 1.487106 loss_l1: 0.936432 loss_contrast: 4.954847 eta: 5:49:36 batch_cost: 0.1533 data_cost: 0.0001 ips: 13.0473 images/s
# [11/06 16:48:49] ppdet.engine INFO: Epoch: [0] [ 600/1349] learning_rate: 0.000009 loss: 3.972884 loss_cls: 1.637015 loss_iou: 0.303522 loss_dfl: 1.556225 loss_l1: 0.950250 loss_contrast: 4.007382 eta: 5:48:01 batch_cost: 0.1525 data_cost: 0.0001 ips: 13.1145 images/s
# [11/06 16:49:07] ppdet.engine INFO: Epoch: [0] [ 700/1349] learning_rate: 0.000010 loss: 3.929785 loss_cls: 1.645379 loss_iou: 0.322113 loss_dfl: 1.518804 loss_l1: 1.023898 loss_contrast: 3.587684 eta: 5:48:15 batch_cost: 0.1570 data_cost: 0.0001 ips: 12.7373 images/s
# [11/06 16:49:25] ppdet.engine INFO: Epoch: [0] [ 800/1349] learning_rate: 0.000012 loss: 3.852930 loss_cls: 1.706248 loss_iou: 0.306537 loss_dfl: 1.511821 loss_l1: 0.990148 loss_contrast: 3.583480 eta: 5:46:32 batch_cost: 0.1505 data_cost: 0.0001 ips: 13.2875 images/s
# [11/06 16:49:42] ppdet.engine INFO: Epoch: [0] [ 900/1349] learning_rate: 0.000013 loss: 3.761530 loss_cls: 1.601029 loss_iou: 0.294130 loss_dfl: 1.409444 loss_l1: 0.835549 loss_contrast: 3.361984 eta: 5:44:21 batch_cost: 0.1472 data_cost: 0.0001 ips: 13.5825 images/s
# [11/06 16:49:59] ppdet.engine INFO: Epoch: [0] [1000/1349] learning_rate: 0.000015 loss: 3.656199 loss_cls: 1.540090 loss_iou: 0.265919 loss_dfl: 1.398263 loss_l1: 0.823556 loss_contrast: 3.406011 eta: 5:43:51 batch_cost: 0.1531 data_cost: 0.0001 ips: 13.0634 images/s
# [11/06 16:50:17] ppdet.engine INFO: Epoch: [0] [1100/1349] learning_rate: 0.000016 loss: 3.634736 loss_cls: 1.572534 loss_iou: 0.288885 loss_dfl: 1.397354 loss_l1: 0.780054 loss_contrast: 3.377697 eta: 5:42:39 batch_cost: 0.1495 data_cost: 0.0001 ips: 13.3793 images/s
# [11/06 16:50:34] ppdet.engine INFO: Epoch: [0] [1200/1349] learning_rate: 0.000018 loss: 3.768035 loss_cls: 1.599819 loss_iou: 0.288637 loss_dfl: 1.431263 loss_l1: 0.828429 loss_contrast: 3.460869 eta: 5:41:33 batch_cost: 0.1490 data_cost: 0.0001 ips: 13.4184 images/s
# [11/06 16:50:52] ppdet.engine INFO: Epoch: [0] [1300/1349] learning_rate: 0.000019 loss: 3.705795 loss_cls: 1.537889 loss_iou: 0.281498 loss_dfl: 1.428260 loss_l1: 0.916138 loss_contrast: 3.379540 eta: 5:41:04 batch_cost: 0.1520 data_cost: 0.0001 ips: 13.1585 images/s
# [11/06 16:51:02] ppdet.utils.checkpoint INFO: Save checkpoint: output/ppyoloe_l_80e_defect_contrast1
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [11/06 16:51:03] ppdet.data.source.coco INFO: Load [464 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/valid/_annotations.coco.json.
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# [11/06 16:51:04] ppdet.engine INFO: Eval iter: 0
# [11/06 16:51:09] ppdet.engine INFO: Eval iter: 100
# [11/06 16:51:14] ppdet.engine INFO: Eval iter: 200
# [11/06 16:51:17] ppdet.metrics.metrics INFO: The bbox result is saved to bbox.json.
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [11/06 16:51:17] ppdet.metrics.coco_utils INFO: Start evaluate...
# Loading and preparing results...
# DONE (t=0.55s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=1.06s).
# Accumulating evaluation results...
# DONE (t=0.48s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.080
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.153
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.074
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.094
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.174
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.319
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.417
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.059
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.111
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.522
# [11/06 16:51:19] ppdet.engine INFO: Total sample number: 464, average FPS: 37.807711548498126
# [11/06 16:51:19] ppdet.engine INFO: Best test bbox ap is 0.080.
# [11/06 16:51:20] ppdet.utils.checkpoint INFO: Save checkpoint: output/ppyoloe_l_80e_defect_contrast1
# [11/06 16:51:21] ppdet.engine INFO: Epoch: [1] [   0/1349] learning_rate: 0.000020 loss: 3.767714 loss_cls: 1.603339 loss_iou: 0.282070 loss_dfl: 1.420674 loss_l1: 0.912601 loss_contrast: 3.422931 eta: 5:42:15 batch_cost: 0.1623 data_cost: 0.0001 ips: 12.3249 images/s
# ^C
# [11/06 16:51:24] reader WARNING: fail to map sample transform [Decode_b199d2] with error: 'bytes' object has no attribute 'shape' and stack:
# Traceback (most recent call last):
#   File "/mnt/e/repository/PaddleDetection/ppdet/data/reader.py", line 214, in __next__
#     return next(self.loader)
#   File "/home/dl/miniconda3/envs/env_common/lib/python3.8/site-packages/paddle/io/dataloader/dataloader_iter.py", line 825, in __next__
#     self._reader.read_next_list()[0]
# StopIteration
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/mnt/e/repository/PaddleDetection/ppdet/data/reader.py", line 59, in __call__
#     data = f(data)
#   File "/mnt/e/repository/PaddleDetection/ppdet/data/transform/operators.py", line 105, in __call__
#     sample = self.apply(sample, context)
#   File "/mnt/e/repository/PaddleDetection/ppdet/data/transform/operators.py", line 139, in apply
#     elif sample['h'] != im.shape[0]:
# AttributeError: 'bytes' object has no attribute 'shape'
#
# Traceback (most recent call last):
#   File "tools/train.py", line 202, in <module>
#     main()
#   File "tools/train.py", line 198, in main
#     run(FLAGS, cfg)
#   File "tools/train.py", line 151, in run
#     trainer.train(FLAGS.eval)
#   File "/mnt/e/repository/PaddleDetection/ppdet/engine/trainer.py", line 537, in train
#     outputs = model(data)
#   File "/home/dl/miniconda3/envs/env_common/lib/python3.8/site-packages/paddle/nn/layer/layers.py", line 1254, in __call__
#     return self.forward(*inputs, **kwargs)
#   File "/mnt/e/repository/PaddleDetection/ppdet/modeling/architectures/meta_arch.py", line 60, in forward
#     out = self.get_loss()
#   File "/mnt/e/repository/PaddleDetection/ppdet/modeling/architectures/yolo.py", line 147, in get_loss
#     return self._forward()
#   File "/mnt/e/repository/PaddleDetection/ppdet/modeling/architectures/yolo.py", line 93, in _forward
#     yolo_losses = self.yolo_head(neck_feats, self.inputs)
#   File "/home/dl/miniconda3/envs/env_common/lib/python3.8/site-packages/paddle/nn/layer/layers.py", line 1254, in __call__
#     return self.forward(*inputs, **kwargs)
#   File "/mnt/e/repository/PaddleDetection/ppdet/modeling/heads/ppyoloe_head.py", line 266, in forward
#     return self.forward_train(feats, targets, aux_pred)
#   File "/mnt/e/repository/PaddleDetection/ppdet/modeling/heads/ppyoloe_contrast_head.py", line 310, in forward_train
#     cls_logit = self.pred_cls[i](self.stem_cls[i](feat, avg_feat) +
#   File "/home/dl/miniconda3/envs/env_common/lib/python3.8/site-packages/paddle/nn/layer/layers.py", line 1254, in __call__
#     return self.forward(*inputs, **kwargs)
#   File "/mnt/e/repository/PaddleDetection/ppdet/modeling/heads/ppyoloe_head.py", line 54, in forward
#     return self.conv(feat * weight)
#   File "/home/dl/miniconda3/envs/env_common/lib/python3.8/site-packages/paddle/nn/layer/layers.py", line 1254, in __call__
#     return self.forward(*inputs, **kwargs)
# KeyboardInterrupt

# %%
# !python E:\repository\defectdet\BDDetection\Bin\Win64\plugin\pythonv3plugin\libs\ppyolo\infer.py \
           --model_dir=E:\repository\defectdet\BDDetection\Bin\Win64\plugin\pythonv3plugin\libs\ppyolo\models \
           --image_file=E:\repository\defectdet\BDDetection\dataddd\input\1701661721.7274697.jpg --device=GPU \
           --output_dir=E:\repository\defectdet\BDDetection\dataddd\vis \
           --slice_infer --slice_size 640 640 --overlap_ratio 0.1 0.1
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# python: can't open file 'E:repositorydefectdetBDDetectionBinWin64pluginpythonv3pluginlibsppyoloinfer.py': [Errno 2] No such file or directory

# %%
# !python /mnt/e/repository/defectdet/BDDetection/Bin/Win64/plugin/pythonv3plugin/libs/ppyolo/infer.py \
        --model_dir=/mnt/e/repository/defectdet/BDDetection/Bin/Win64/plugin/pythonv3plugin/libs/ppyolo/models \
        --image_file=/mnt/e/repository/defectdet/BDDetection/dataddd/input/1701661721.7274697.jpg --device=GPU \
        --output_dir=/mnt/e/repository/defectdet/BDDetection/dataddd/vis \
        --slice_infer --slice_size 640 640 --overlap_ratio 0.1 0.1
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# -----------  Running Arguments -----------
# action_file: None
# batch_size: 1
# camera_id: -1
# combine_method: nms
# cpu_threads: 1
# device: GPU
# enable_mkldnn: False
# enable_mkldnn_bfloat16: False
# image_dir: None
# image_file: /mnt/e/repository/defectdet/BDDetection/dataddd/input/1701661721.7274697.jpg
# match_metric: ios
# match_threshold: 0.6
# model_dir: /mnt/e/repository/defectdet/BDDetection/Bin/Win64/plugin/pythonv3plugin/libs/ppyolo/models
# output_dir: /mnt/e/repository/defectdet/BDDetection/dataddd/vis
# overlap_ratio: [0.1, 0.1]
# random_pad: False
# reid_batch_size: 50
# reid_model_dir: None
# run_benchmark: False
# run_mode: paddle
# save_images: True
# save_mot_txt_per_img: False
# save_mot_txts: False
# save_results: False
# scaled: False
# slice_infer: True
# slice_size: [640, 640]
# threshold: 0.5
# tracker_config: None
# trt_calib_mode: False
# trt_max_shape: 1280
# trt_min_shape: 1
# trt_opt_shape: 640
# use_coco_category: False
# use_dark: True
# use_gpu: False
# video_file: None
# window_size: 50
# ------------------------------------------
# -----------  Model Configuration -----------
# Model Arch: YOLO
# Transform Order:
# --transform op: Resize
# --transform op: NormalizeImage
# --transform op: Permute
# --------------------------------------------
# slice to {} sub_samples. 28
# class_id:1, confidence:0.6044, left_top:[1618.30,1533.09],right_bottom:[1791.98,1647.20]
# class_id:1, confidence:0.8935, left_top:[1728.60,1583.51],right_bottom:[2197.83,1663.95]
# class_id:1, confidence:0.5602, left_top:[1727.97,1284.18],right_bottom:[2115.72,1407.47]
# class_id:5, confidence:0.5072, left_top:[1727.82,10.70],right_bottom:[2363.74,638.91]
# class_id:5, confidence:0.5753, left_top:[2886.21,4.55],right_bottom:[3519.53,638.43]
# class_id:5, confidence:0.5773, left_top:[3200.81,37.59],right_bottom:[3817.17,620.22]
# class_id:6, confidence:0.6737, left_top:[662.22,1152.65],right_bottom:[1216.00,1438.14]
# save result to: /mnt/e/repository/defectdet/BDDetection/dataddd/vis/1701661721.7274697.jpg
# Test iter 0
# {'boxes': array([[ 1.00000000e+00,  2.34735414e-01,  1.13580322e+00,
#          2.43429565e+00,  6.39046509e+02,  6.38360474e+02],
#        [ 1.00000000e+00,  1.09444689e-02, -7.16477814e+01,
#         -2.80332947e+01,  2.25842041e+02,  9.87610245e+01],
#        [ 1.00000000e+00,  3.24083418e-01,  5.76481323e+02,
#          1.35906982e+00,  1.21585254e+03,  6.38066833e+02],
#        ...,
#        [ 6.00000000e+00,  3.85343991e-02,  2.30424658e+03,
#          1.79097729e+03,  2.85075244e+03,  1.87782349e+03],
#        [ 6.00000000e+00,  1.59412418e-02,  2.87318042e+03,
#          1.85879126e+03,  3.51701416e+03,  1.91939014e+03],
#        [ 6.00000000e+00,  5.05008586e-02,  3.21568188e+03,
#          1.28067566e+03,  3.81795581e+03,  1.62613232e+03]]), 'boxes_num': array([714], dtype=int32)}
# ------------------ Inference Time Info ----------------------
# total_time(ms): 3155.2, img_num: 1
# average latency time(ms): 3155.20, QPS: 0.316937
# preprocess_time(ms): 125.20, inference_time(ms): 3030.00, postprocess_time(ms): 0.00
