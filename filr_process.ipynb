# %%
msx_dir = r'/mnt/e/data/polyu/data202311/msx'
msx_img_dir = r'/mnt/e/data/polyu/data202311/msx_img'
thermal_dir = r'/mnt/e/data/polyu/data202311/thermal'
thermal_img_dir = r'/mnt/e/data/polyu/data202311/thermal_img'

# %%
import os, shutil
from tqdm import tqdm

def move2dir(input_dir, output_dir):
    file_list = os.listdir(input_dir)
    for file_name in tqdm(file_list):
        file_num = int(file_name[4:8])
        if file_num%2==1:
            continue
            
        input_path = os.path.join(input_dir, file_name)
        output_path = os.path.join(output_dir, file_name.replace(str(file_num), str(file_num-1)))
        shutil.move(input_path, output_path)

# %%
move2dir(msx_dir, msx_img_dir)
# Out:
# 100%|██████████| 342/342 [00:01<00:00, 274.25it/s]

# %%
move2dir(thermal_dir, thermal_img_dir)
# Out:
# 100%|██████████| 242/242 [00:01<00:00, 235.39it/s]

# %%
import numpy as np
import scipy.ndimage
from skimage import io

def rsimg2dir(input_dir, output_dir):
    file_list = os.listdir(input_dir)
    for file_name in tqdm(file_list):
        img = io.imread(os.path.join(input_dir, file_name))

        img_upsampled = scipy.ndimage.zoom(img, (2, 2, 1))

        io.imsave(os.path.join(output_dir, file_name), img_upsampled)

# %%
msx2x_dir = r'/mnt/e/data/polyu/data202311/msx_2x'
thermal2x_dir = r'/mnt/e/data/polyu/data202311/thermal_2x'

# %%
rsimg2dir(thermal_dir, thermal2x_dir)
# Out:
# 100%|██████████| 121/121 [00:27<00:00,  4.42it/s]

# %%
rsimg2dir(msx_dir, msx2x_dir)
# Out:
# 100%|██████████| 171/171 [00:39<00:00,  4.36it/s]

# %%
# !python tools/x2coco.py \
        --dataset_type labelme \
        --json_input_dir /mnt/e/data/polyu/data202311/msx_img \
        --image_input_dir /mnt/e/data/polyu/data202311/msx_img \
        --output_dir /mnt/e/data/polyu/data202311/msx_coco \
        --train_proportion 0.8 \
        --val_proportion 0.2
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_img/FLIR3677.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_img/FLIR3689.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_img/FLIR3693.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_img/FLIR3695.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_img/FLIR3697.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_img/FLIR3699.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_img/FLIR3701.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_img/FLIR3703.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_img/FLIR3705.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_img/FLIR3707.json
# ...

# %%
# !python tools/x2coco.py \
        --dataset_type labelme \
        --json_input_dir /mnt/e/data/polyu/data202311/msx_2x \
        --image_input_dir /mnt/e/data/polyu/data202311/msx_2x \
        --output_dir /mnt/e/data/polyu/data202311/msx_2x_coco \
        --train_proportion 0.8 \
        --val_proportion 0.2
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_2x/FLIR3677.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_2x/FLIR3689.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_2x/FLIR3693.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_2x/FLIR3695.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_2x/FLIR3697.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_2x/FLIR3699.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_2x/FLIR3701.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_2x/FLIR3703.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_2x/FLIR3705.json
# Generating dataset from: /mnt/e/data/polyu/data202311/msx_2x/FLIR3707.json
# ...

# %%
# !python tools/x2coco.py \
        --dataset_type labelme \
        --json_input_dir /mnt/e/data/polyu/data202311/thermal_img \
        --image_input_dir /mnt/e/data/polyu/data202311/thermal_img \
        --output_dir /mnt/e/data/polyu/data202311/thermal_coco \
        --train_proportion 0.8 \
        --val_proportion 0.2
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_img/FLIR3685.json
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_img/FLIR3771.json
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_img/FLIR3861.json
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_img/FLIR3863.json
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_img/FLIR3865.json
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_img/FLIR3867.json
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_img/FLIR3869.json
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_img/FLIR3875.json
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_img/FLIR3877.json
# ...

# %%
# !python tools/x2coco.py \
        --dataset_type labelme \
        --json_input_dir /mnt/e/data/polyu/data202311/thermal_2x \
        --image_input_dir /mnt/e/data/polyu/data202311/thermal_2x \
        --output_dir /mnt/e/data/polyu/data202311/thermal_2x_coco \
        --train_proportion 0.8 \
        --val_proportion 0.2
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_2x/FLIR3685.json
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_2x/FLIR3771.json
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_2x/FLIR3861.json
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_2x/FLIR3863.json
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_2x/FLIR3865.json
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_2x/FLIR3867.json
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_2x/FLIR3869.json
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_2x/FLIR3875.json
# Generating dataset from: /mnt/e/data/polyu/data202311/thermal_2x/FLIR3877.json
# ...

# %%
# !python tools/x2coco.py \
        --dataset_type labelme \
        --json_input_dir /mnt/e/data/polyu/data202311/mt_2x \
        --image_input_dir /mnt/e/data/polyu/data202311/mt_2x \
        --output_dir /mnt/e/data/polyu/data202311/mt_2x_coco \
        --train_proportion 0.8 \
        --val_proportion 0.2
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_2x/FLIR3677.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_2x/FLIR3685.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_2x/FLIR3689.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_2x/FLIR3693.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_2x/FLIR3695.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_2x/FLIR3697.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_2x/FLIR3699.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_2x/FLIR3701.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_2x/FLIR3703.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_2x/FLIR3705.json
# ...

# %%
# !python tools/x2coco.py \
        --dataset_type labelme \
        --json_input_dir /mnt/e/data/polyu/data202311/mt_img \
        --image_input_dir /mnt/e/data/polyu/data202311/mt_img \
        --output_dir /mnt/e/data/polyu/data202311/mt_img_coco \
        --train_proportion 0.8 \
        --val_proportion 0.2
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_img/FLIR3677.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_img/FLIR3685.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_img/FLIR3689.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_img/FLIR3693.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_img/FLIR3695.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_img/FLIR3697.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_img/FLIR3699.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_img/FLIR3701.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_img/FLIR3703.json
# Generating dataset from: /mnt/e/data/polyu/data202311/mt_img/FLIR3705.json
# ...

# %%
# !python tools/train.py \
    -c configs/data202311/data202311_msx_img_ppyoloe.yml \
    --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [11/22 22:04:59] ppdet.data.source.coco INFO: Load [54 samples valid, 0 samples invalid] in file /mnt/e/data/polyu/data202311/msx_coco/annotations/instance_train.json.
# W1122 22:04:59.272049 1738351 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1122 22:04:59.309603 1738351 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/22 22:05:06] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [2] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# !python tools/train.py \
    -c configs/data202311/data202311_msx_ppyoloe.yml \
    --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...

# %%
# !python tools/train.py \
    -c configs/data202311/data202311_thermal_img_ppyoloe.yml \
    --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)

# %%
# !python tools/train.py \
    -c configs/data202311/data202311_thermal_img_ppyoloe.yml \
    --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)

# %%
# !python tools/train.py \
    -c configs/data202311/data202311_mt_img_ppyoloe.yml \
    --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# [11/22 23:02:24] ppdet.data.source.coco INFO: Load [93 samples valid, 0 samples invalid] in file /mnt/e/data/polyu/data202311/mt_img_coco/annotations/instance_train.json.
# W1122 23:02:24.870611 1760691 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1122 23:02:24.956598 1760691 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/22 23:02:37] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [2] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# !python tools/train.py \
    -c configs/data202311/data202311_mt_ppyoloe.yml \
    --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [11/23 00:33:35] ppdet.data.source.coco INFO: Load [93 samples valid, 0 samples invalid] in file /mnt/e/data/polyu/data202311/mt_2x_coco/annotations/instance_train.json.
# W1123 00:33:35.905867 1788561 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1123 00:33:35.979070 1788561 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/23 00:49:22] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [2] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# json_to_dataset.py
import argparse
import json
import os
import os.path as osp
import warnings
import imgviz
import PIL.Image
import yaml
from skimage import io
from labelme import utils
import base64
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

def main():
    input_dir = "/mnt/e/data/polyu/data202311seg/mt_img"
    output_dir = "/mnt/e/data/polyu/data202311seg/mt_img_segset"
    output_img_dir = "/mnt/e/data/polyu/data202311seg/mt_img_segset/img"
    output_gt_dir = "/mnt/e/data/polyu/data202311seg/mt_img_segset/gt"
    output_vis_dir = "/mnt/e/data/polyu/data202311seg/mt_img_segset/vis"
    
    if not osp.exists(output_img_dir):
        os.makedirs(output_img_dir)
    if not osp.exists(output_gt_dir):
        os.makedirs(output_gt_dir)
    if not osp.exists(output_vis_dir):
        os.makedirs(output_vis_dir)
        
    count = os.listdir(input_dir) 
    
    for i in tqdm(range(0, len(count))):
        path = os.path.join(input_dir, count[i])
 
        # 找到before文件中以json为结尾的文件并且打开
        if os.path.isfile(path) and path.endswith('json'):
            data = json.load(open(path))
            
            if data['imageData']:
                imageData = data['imageData']
            else:
                imagePath = os.path.join(os.path.dirname(path), data['imagePath'])
                with open(imagePath, 'rb') as f:
                    imageData = f.read()
                    imageData = base64.b64encode(imageData).decode('utf-8')
            img = utils.img_b64_to_arr(imageData)
            label_name_to_value = {'_background_': 0}
            for shape in data['shapes']:
                label_name = shape['label']
                if label_name in label_name_to_value:
                    label_value = label_name_to_value[label_name]
                else:
                    label_value = len(label_name_to_value)
                    label_name_to_value[label_name] = label_value
            
            # label_values must be dense
            label_values, label_names = [], []
            for ln, lv in sorted(label_name_to_value.items(), key=lambda x: x[1]):
                label_values.append(lv)
                label_names.append(ln)
            assert label_values == list(range(len(label_values)))
            
            lbl, _ = utils.shapes_to_label(img.shape, data['shapes'], label_name_to_value)
 
            # captions = ['{}: {}'.format(lv, ln)
            #     for ln, lv in label_name_to_value.items()]
            # lbl_viz = utils.labelme_shapes_to_label(lbl, img, captions)
            label_names = [None] * (max(label_name_to_value.values()) + 1)
            for name, value in label_name_to_value.items():
                label_names[value] = name
 
            lbl_viz = imgviz.label2rgb(
                lbl, imgviz.asgray(img), label_names=label_names, loc="rb"
            )
 
            # out_dir = osp.basename(count[i]).replace('.', '_')
            # out_dir = osp.join(osp.dirname(count[i]), out_dir)
            # out_dir = osp.join("output",out_dir)
            # 
            # if not osp.exists(out_dir):
            #     os.mkdir(out_dir)
            # image
            # PIL.Image.fromarray(img).save(osp.join(out_dir, 'img.png'))
            # label.png
            # utils.lblsave(osp.join(out_dir, 'label.png'), lbl)
            # PIL.Image.fromarray(lbl_viz).save(osp.join(out_dir, 'label_viz.png'))
            # label_viz.png
            # PIL.Image.fromarray(lbl_viz).save(osp.join(out_dir, "label_viz.png"))
            # print(img.dtype, img.shape, np.max(img), np.min(img))
            io.imsave(osp.join(output_img_dir, count[i].replace('.json', '.png')), img)
            io.imsave(osp.join(output_gt_dir, count[i].replace('.json', '.png')), lbl)
            io.imsave(osp.join(output_vis_dir, count[i].replace('.json', '.png')), lbl_viz)
 
            with open(osp.join(output_dir, 'label_names.txt'), 'w') as f:
                for lbl_name in label_names:
                    f.write(lbl_name + '\n')
 
            # warnings.warn('info.yaml is being replaced by label_names.txt')
            # info = dict(label_names=label_names)
            # with open(osp.join(out_dir, 'info.yaml'), 'w') as f:
            #     yaml.safe_dump(info, f, default_flow_style=False)
 
            # print('Saved to: %s' % output_dir)
 
if __name__ == '__main__':
    main()
# Out:
# 100%|██████████| 511/511 [00:40<00:00, 12.64it/s]
