# %% [markdown]
# # few shot comparision on Defect Dataset

# %%
# shot10
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_shot10.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# [11/15 21:36:47] ppdet.data.source.coco INFO: Load [60 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/shot10_annotations.coco.json.
# W1115 21:36:47.182163 19936 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1115 21:36:47.196396 19936 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/15 21:36:50] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# shot50
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_shot50.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [11/15 22:43:42] ppdet.data.source.coco INFO: Load [299 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/shot50_annotations.coco.json.
# W1115 22:43:42.965315 44769 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1115 22:43:42.969560 44769 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/15 22:43:45] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# shot100
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_shot100.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# [11/16 05:23:00] ppdet.data.source.coco INFO: Load [597 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/shot100_annotations.coco.json.
# W1116 05:23:00.260434 125932 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1116 05:23:00.266839 125932 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/16 05:23:02] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# shot10
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_contrast_shot10.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# [11/16 13:10:49] ppdet.data.source.coco INFO: Load [60 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/shot10_annotations.coco.json.
# W1116 13:10:49.158699 218107 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1116 13:10:49.164142 218107 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/16 13:10:51] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# shot50
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_contrast_shot50.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# [11/16 14:26:42] ppdet.data.source.coco INFO: Load [299 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/shot50_annotations.coco.json.
# W1116 14:26:42.360286 244406 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1116 14:26:42.366200 244406 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/16 14:26:44] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# shot100
# !python tools/train.py \
        -c configs/ppyoloe/ppyoloe_l_80e_defect_contrast_shot100.yml \
        --eval
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# ...
# loading annotations into memory...
# Done (t=0.02s)
# creating index...
# index created!
# [11/16 19:54:36] ppdet.data.source.coco INFO: Load [597 samples valid, 0 samples invalid] in file /mnt/e/data/DefectDet/train/shot100_annotations.coco.json.
# W1116 19:54:36.423961 312810 gpu_resources.cc:119] Please NOTE: device: 0, GPU Compute Capability: 8.9, Driver API Version: 12.2, Runtime API Version: 11.6
# W1116 19:54:36.454026 312810 gpu_resources.cc:149] device: 0, cuDNN Version: 8.4.
# [11/16 19:54:41] ppdet.utils.checkpoint INFO: The shape [365] in pretrained weight yolo_head.pred_cls.0.bias is unmatched with the shape [7] in model yolo_head.pred_cls.0.bias. And the weight yolo_head.pred_cls.0.bias will not be loaded
# ...

# %%
# !python tools/x2coco.py \
        --dataset_type labelme \
        --json_input_dir /mnt/e/data/polyu/js_src \
        --image_input_dir /mnt/e/data/polyu/img_src \
        --output_dir /mnt/e/data/polyu/dataset_coco \
        --train_proportion 0.8 \
        --val_proportion 0.2
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Generating dataset from: /mnt/e/data/polyu/js_src/IMG_20231111_162829.json
# Generating dataset from: /mnt/e/data/polyu/js_src/IMG_20231111_163005.json
# Generating dataset from: /mnt/e/data/polyu/js_src/IMG_20231111_163155.json
# Generating dataset from: /mnt/e/data/polyu/js_src/IMG_20231111_163158.json
# Generating dataset from: /mnt/e/data/polyu/js_src/IMG_20231111_163200.json
# Generating dataset from: /mnt/e/data/polyu/js_src/IMG_20231111_163204.json
# Generating dataset from: /mnt/e/data/polyu/js_src/IMG_20231111_163206.json
# Generating dataset from: /mnt/e/data/polyu/js_src/IMG_20231111_163209.json
# Generating dataset from: /mnt/e/data/polyu/js_src/IMG_20231111_163212.json
# Generating dataset from: /mnt/e/data/polyu/js_src/IMG_20231111_163220.json
# ...

# %%
# !python tools/slice_image.py \
        --image_dir /mnt/e/data/polyu/dataset_coco/train \
        --json_path /mnt/e/data/polyu/dataset_coco/annotations/instance_train.json \
        --output_dir /mnt/e/data/polyu/dataset_coco/train_slice \
        --slice_size 640 \
        --overlap_ratio 0.2
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
#  slicing for slice_size=640, overlap_ratio=0.2
# Slicing step is starting...
# indexing coco dataset annotations...
# ...
# 100%|███████████████████████████████████████████| 40/40 [00:28<00:00,  1.42it/s]
# Sliced dataset for 'slice_size: 640' is exported to /mnt/e/data/polyu/dataset_coco/train_slice

# %%
# !python tools/slice_image.py \
        --image_dir /mnt/e/data/polyu/dataset_coco/val \
        --json_path /mnt/e/data/polyu/dataset_coco/annotations/instance_val.json \
        --output_dir /mnt/e/data/polyu/dataset_coco/val_slice \
        --slice_size 640 \
        --overlap_ratio 0.2
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
#  slicing for slice_size=640, overlap_ratio=0.2
# indexing coco dataset annotations...
# ...
# 100%|███████████████████████████████████████████| 19/19 [00:02<00:00,  7.72it/s]

# %%
# 对于有标注的数据进行切图
# !python configs/rotate/tools/prepare_data.py \
    --input_dirs /mnt/e/data/polyu/dataset_coco/val \
    --output_dir /mnt/e/data/polyu/dataset_coco/val_slice \
    --coco_json_file /mnt/e/data/polyu/dataset_coco/annotations/instance_val.json \
    --subsize 640 \
    --gap 500 \
    --rates 1.0

# # 对于无标注的数据进行切图需要设置--image_only
# !python configs/rotate/tools/prepare_data.py \
#     --input_dirs ${DOTA_ROOT}/test/ \
#     --output_dir ${OUTPUT_DIR}/test1024/ \
#     --coco_json_file DOTA_test1024.json \
#     --subsize 1024 \
#     --gap 200 \
#     --rates 1.0 \
#     --image_only
# Out:
# /bin/bash: /home/dl/miniconda3/envs/env_common/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# /bin/bash: warning: setlocale: LC_ALL: cannot change locale (en_US.UTF-8)
# Traceback (most recent call last):
#   File "configs/rotate/tools/prepare_data.py", line 128, in <module>
#     main()
#   File "configs/rotate/tools/prepare_data.py", line 111, in main
#     infos += load_dataset(input_dir, args.nproc, args.data_type)
#   File "configs/rotate/tools/prepare_data.py", line 100, in load_dataset
#     infos = load_dota_infos(input_dir, nproc)
#   File "/mnt/e/repository/PaddleDetection/configs/rotate/tools/convert.py", line 59, in load_dota_infos
#     for file_name in os.listdir(image_dir):
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/e/data/polyu/dataset_coco/val/images'

# %%
from sahi.slicing import slice_image
slice_image(
image='/mnt/e/data/polyu/dataset_coco/val/IMG_20231111_163634.jpg',
output_file_name='IMG_20231111_163634.jpg',
output_dir='/mnt/e/data/polyu/dataset_coco/val_slice',
slice_height=500,
slice_width=500,
overlap_height_ratio=0.1,
overlap_width_ratio=0.1,
)
